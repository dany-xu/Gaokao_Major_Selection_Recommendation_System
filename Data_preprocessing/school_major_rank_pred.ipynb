# %% [markdown]
# # 预测

# %%
import pandas as pd

# %%
df1.to_csv('df120210728.csv',encoding='gbk',index=None)

# %%
ranking=pd.read_csv('7.21/ranking.csv',encoding='gbk',header=None)
df1=pd.read_csv('df120210728.csv',encoding='gbk')
df1
# Out:
#            id           majorName  year  minScore  categoryID_id  \
# 0           0                计算机类  2020       622            2.0
# 1           1                 数学类  2020       621            2.0
# 2           2                 机械类  2020       621            2.0
# 3           3                土木工程  2020       620            2.0
# 4           4                经济学类  2020       620            2.0
# ...       ...                 ...   ...       ...            ...
# 3335  5528704  野生动物与自然保护区管理（国家专项）  2020       611            2.0
# 3336  5531969    计算机科学与技术(中外合作办学)  2020       589            2.0
# 3337  5535235          化学(中外合作办学)  2020       577            2.0
# 3338  5538502        生物技术(中外合作办学)  2020       575            2.0
# 3339  5541770        工程管理(中外合作办学)  2020       547            2.0
#
#       collegeID_id   c1          c2 college_loc provinceLoc cityLoc  adcode  \
# 0            10593   工学        计算机类      广西省南宁市     广西壮族自治区     南宁市  450100
# ...

# %%
df1.describe()['minScore']['min']
# Out:
# 316.0

# %%
ur120
# Out:
#              0     1    2       3  4  5
# 30371   699117  2020  671      11  1  1
# 30372   700275  2020  670      13  1  1
# 30373   701434  2020  669      17  1  1
# 30374   702594  2020  668      18  1  1
# 30375   703755  2020  667      23  1  1
# ...        ...   ...  ...     ... .. ..
# 31337  2283840  2020  320  382059  2  1
# 31338  2285964  2020  319  382852  2  1
# 31339  2288089  2020  318  383618  2  1
# 31340  2290215  2020  317  384391  2  1
# 31341  2292342  2020  316  385137  2  1
#
# [756 rows x 6 columns]

# %%
r1=ranking[ranking[5]==1]

# %%
r120=r1[r1[1]==2020]

# %%
ur120=r120[r120[2]>=df1.describe()['minScore']['min']]

# %%
ur1201=ur120[ur120[4]==1]
ur1202=ur120[ur120[4]==2]

# %%
s_r1=dict(zip(ur1201[2],ur1201[3]))
s_r2=dict(zip(ur1202[2],ur1202[3]))
s_r1
# Out:
# {671: 11,
#  670: 13,
#  669: 17,
#  668: 18,
#  667: 23,
#  666: 28,
#  665: 33,
#  664: 34,
#  663: 40,
#  662: 46,
#  661: 54,
#  660: 59,
#  659: 65,
#  658: 75,
#  657: 83,
#  656: 92,
#  655: 104,
#  654: 116,
#  653: 131,
#  652: 147,
#  651: 157,
#  650: 175,
#  649: 197,
#  648: 212,
#  647: 235,
#  646: 259,
#  645: 285,
#  644: 316,
#  643: 345,
#  642: 370,
#  641: 412,
#  640: 449,
#  639: 487,
#  638: 528,
#  637: 568,
#  636: 625,
#  635: 669,
#  634: 719,
#  633: 786,
#  632: 840,
#  631: 925,
#  630: 989,
#  629: 1077,
#  628: 1146,
#  627: 1221,
#  626: 1298,
#  625: 1401,
#  624: 1479,
#  623: 1563,
#  622: 1657,
#  621: 1757,
#  620: 1856,
#  619: 1981,
#  618: 2080,
#  617: 2213,
#  616: 2360,
#  615: 2509,
#  614: 2635,
#  613: 2756,
#  612: 2903,
#  611: 3072,
#  610: 3216,
#  609: 3375,
#  608: 3546,
#  607: 3712,
#  606: 3880,
#  605: 4047,
#  604: 4240,
#  603: 4444,
#  602: 4631,
#  601: 4835,
#  600: 5041,
#  599: 5253,
#  598: 5502,
#  597: 5757,
# ...

# %%
for i in range(df1.shape[0]):
    if df1.at[i,'categoryID_id']==1:
        if df1.at[i,'minScore']>max(ur1201[2]):
            df1.at[i,'preRanking']=min(ur1201[3])
        else:
            df1.at[i,'preRanking']=s_r1[df1.at[i,'minScore']]
    else:
        if df1.at[i,'minScore']>max(ur1202[2]):
            df1.at[i,'preRanking']=min(ur1202[3])
        else:
            df1.at[i,'preRanking']=s_r2[df1.at[i,'minScore']]
df1
# Out:
#            id           majorName  year  minScore  categoryID_id  \
# 0           0                计算机类  2020       622            2.0
# 1           1                 数学类  2020       621            2.0
# 2           2                 机械类  2020       621            2.0
# 3           3                土木工程  2020       620            2.0
# 4           4                经济学类  2020       620            2.0
# ...       ...                 ...   ...       ...            ...
# 3335  5528704  野生动物与自然保护区管理（国家专项）  2020       611            2.0
# 3336  5531969    计算机科学与技术(中外合作办学)  2020       589            2.0
# 3337  5535235          化学(中外合作办学)  2020       577            2.0
# 3338  5538502        生物技术(中外合作办学)  2020       575            2.0
# 3339  5541770        工程管理(中外合作办学)  2020       547            2.0
#
#       collegeID_id   c1          c2 college_loc provinceLoc cityLoc  adcode  \
# 0            10593   工学        计算机类      广西省南宁市     广西壮族自治区     南宁市  450100
# ...

# %%
df1[df1['collegeID_id']==10001]
# Out:
#            id          majorName  year  minScore  categoryID_id  collegeID_id  \
# 1642  1435030              工商管理类  2020       709            2.0         10001
# 1643  1436602             理科试验班类  2020       708            2.0         10001
# 1644  1438175                数学类  2020       706            2.0         10001
# 1645  1439749                 法学  2020       705            2.0         10001
# 1646  1441324               计算机类  2020       705            2.0         10001
# 1647  1442900               物理学类  2020       704            2.0         10001
# 1648  1444477                化学类  2020       704            2.0         10001
# 1649  1446055             工科试验班类  2020       703            2.0         10001
# 1650  1447634               经济学类  2020       703            2.0         10001
# 1651  1449214              电子信息类  2020       703            2.0         10001
# 1652  1450795            人文科学试验班  2020       679            1.0         10001
# ...

# %%
df1.to_csv('alldata1.0.csv',encoding='gbk',index=None)
